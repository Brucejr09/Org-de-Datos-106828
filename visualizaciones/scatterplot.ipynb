# %%
from pandas import read_csv
from funciones import tipo_transferencia, dia, scatter

transactions = read_csv("C:\\Users\\palej\\Desktop\\FIUBA\\Organizacion de datos\\TP\\transactions_train.csv")

# %%
#                   VISUALIZACION       DE      SCATTERPLOT

# %%
analisis = transactions[["target", "ammount", "timestamp"]]

# %%
analisis = analisis.rename(columns={"target":"Transferencia", "ammount":"Monto", "timestamp":"Tiempo"})

# %%
analisis["Transferencia"] = analisis["Transferencia"].map(tipo_transferencia)

# %%
analisis["Tiempo"] = analisis["Tiempo"].map(dia)

# %%
analisis_legal = analisis[ analisis.Transferencia == "Legal" ][ ["Monto", "Tiempo"] ]

# %%
analisis_legal
# Out:
#          Monto  Tiempo
# 0        68.50       0
# 1        29.00       1
# 2        59.00       1
# 3        50.00       1
# 4        50.00       1
# ...        ...     ...
# 501954   29.00     152
# 501955  312.95     152
# 501956  774.00     152
# 501957  226.00     152
# 501958   97.00     152
#
# [484379 rows x 2 columns]

# %%
analisis_fraude = analisis[ analisis.Transferencia == "Fraude" ][ ["Monto", "Tiempo"] ]

# %%
analisis_fraude
# Out:
#           Monto  Tiempo
# 203     445.000       1
# 240      37.098       1
# 243      37.098       1
# 245      37.098       1
# 288     155.521       1
# ...         ...     ...
# 501935   34.552     152
# 501936   34.552     152
# 501941  250.000     152
# 501942  100.000     152
# 501945   54.000     152
#
# [17580 rows x 2 columns]

# %%
numero = 6000
x1 = analisis_legal[ analisis_legal.Monto <= numero ]["Tiempo"]
x2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Tiempo"]
y1 = analisis_legal[ analisis_legal.Monto <= numero ]["Monto"]
y2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Monto"]
scatter(x1, x2, y1, y2)
# Out:
# C:\Users\palej\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
numero = 2000
x1 = analisis_legal[ analisis_legal.Monto <= numero ]["Tiempo"]
x2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Tiempo"]
y1 = analisis_legal[ analisis_legal.Monto <= numero ]["Monto"]
y2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Monto"]
scatter(x1, x2, y1, y2)

# %%
numero = 1250
x1 = analisis_legal[ analisis_legal.Monto <= numero ]["Tiempo"]
x2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Tiempo"]
y1 = analisis_legal[ analisis_legal.Monto <= numero ]["Monto"]
y2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Monto"]
scatter(x1, x2, y1, y2)

# %%
numero = 500
x1 = analisis_legal[ analisis_legal.Monto <= numero ]["Tiempo"]
x2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Tiempo"]
y1 = analisis_legal[ analisis_legal.Monto <= numero ]["Monto"]
y2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Monto"]
scatter(x1, x2, y1, y2)

# %%
numero = 300
x1 = analisis_legal[ analisis_legal.Monto <= numero ]["Tiempo"]
x2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Tiempo"]
y1 = analisis_legal[ analisis_legal.Monto <= numero ]["Monto"]
y2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Monto"]
scatter(x1, x2, y1, y2)

# %%
numero = 150
x1 = analisis_legal[ analisis_legal.Monto <= numero ]["Tiempo"]
x2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Tiempo"]
y1 = analisis_legal[ analisis_legal.Monto <= numero ]["Monto"]
y2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Monto"]
scatter(x1, x2, y1, y2)

# %%
numero = 50
x1 = analisis_legal[ analisis_legal.Monto <= numero ]["Tiempo"]
x2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Tiempo"]
y1 = analisis_legal[ analisis_legal.Monto <= numero ]["Monto"]
y2 = analisis_fraude[ analisis_fraude.Monto <= numero ]["Monto"]
scatter(x1, x2, y1, y2)
